# %%
from sphfile import SPHFile
import os
from pydub import AudioSegment

# %%
dr1='TIMIT/TRAIN/DR1'
sa1='/SA1.WAV'
sa2='/SA2.WAV'
dr1=[os.path.join(dr1,p) for p in sorted(os.listdir(dr1))]
dr1_list_sa1=[]
for i in dr1:
    dr1_list_sa1.append(os.path.join(i,'SA1.WAV'))

dr1_sa1=[os.path.join(dr1,sa1)]

# %%
# for i in dr2_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# for i in dr3_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# for i in dr4_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# for i in dr5_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# for i in dr6_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# for i in dr7_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# for i in dr8_list_sa1:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA1.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)

# for i in dr1_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr2_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr3_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr4_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr5_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr6_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr7_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
# for i in dr8_list_sa2:
#     x=i.split('\\')
#     x[2]#name
#     sph=SPHFile(i)
#     a=os.path.join(x[0],x[1])
#     txt=os.path.join(a,x[2])
#     txt=os.path.join(txt,'SA2.txt')
#     f = open(txt, "r")
#     for line in f:
#         t=line.split(" ")
#         start_time=(int(t[0])/16000)
#         end_time=(int(t[1])/16000)
#     sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)

# %%
"""sph =SPHFile(
    'TRAIN\\DR2\\FAEM0\\SA1.WAV'
)
sph.write_wav( 'test.wav',0,3.36)
"""

for i in dr1_list_sa1:
    x=i.split('/')
    print("Hello")
    print(i)
    x[2]#name
    #print(x)
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2],x[3])
    txt1=os.path.join(txt,'SA1.TXT')
    wrd=os.path.join(txt,'SA1.WRD')
    f = open(txt1, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav(filename=i.replace(".WAV","_.wav"))
# Out:
# Hello
# TIMIT/TRAIN/DR1/FCJF0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FDAW0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FDML0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FECD0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FETB0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FJSP0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FKFB0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FMEM0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FSAH0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FSJK1/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FSMA0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FTBR0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FVFB0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/FVMH0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MCPM0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MDAC0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MDPK0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MEDR0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MGRL0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MJEB1/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MJWT0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MKLS0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MKLW0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MMGG0/SA1.WAV
# Hello
# TIMIT/TRAIN/DR1/MMRP0/SA1.WAV
# ...

# %%
"""#divide song at word level
from pydub import AudioSegment
for i in dr1:
    dr1_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr2:
    dr2_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr3:
    dr3_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr4:
    dr4_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr5:
    dr5_list_sa1.append(os.path.join(i,'SA1.WRD'))    
for i in dr6:
    dr6_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr7:
    dr7_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr8:
    dr8_list_sa1.append(os.path.join(i,'SA1.WRD'))
for i in dr1:
    dr1_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr2:
    dr2_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr3:
    dr3_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr4:
    dr4_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr5:
    dr5_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr6:
    dr6_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr7:
    dr7_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr8:
    dr8_list_sa2.append(os.path.join(i,'SA2.WRD'))
for i in dr1_list_sa1:
    f = open(i, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr2_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr3_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr4_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr5_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr6_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr7_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
for i in dr8_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA1.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)

for i in dr1_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr2_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr3_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr4_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr5_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr6_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr7_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
for i in dr8_list_sa2:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt=os.path.join(txt,'SA2.txt')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa2\\'+x[2]+'_sa2.WAV',start_time,end_time)
#for line in f:
#    t=line.split(" ")
#start_time=int(t[0])/16000
#end_time=int(t[1])/16000"""
# Out:
# '#divide song at word level\nfrom pydub import AudioSegment\nfor i in dr1:\n    dr1_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr2:\n    dr2_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr3:\n    dr3_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr4:\n    dr4_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr5:\n    dr5_list_sa1.append(os.path.join(i,\'SA1.WRD\'))    \nfor i in dr6:\n    dr6_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr7:\n    dr7_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr8:\n    dr8_list_sa1.append(os.path.join(i,\'SA1.WRD\'))\nfor i in dr1:\n    dr1_list_sa2.append(os.path.join(i,\'SA2.WRD\'))\nfor i in dr2:\n    dr2_list_sa2.append(os.path.join(i,\'SA2.WRD\'))\nfor i in dr3:\n    dr3_list_sa2.append(os.path.join(i,\'SA2.WRD\'))\nfor i in dr4:\n    dr4_list_sa2.append(os.path.join(i,\'SA2.WRD\'))\nfor i in dr5:\n    dr5_list_sa2.append(os.path.join(i,\'SA2.WRD\'))\nfor i in dr6:\n    dr6_list_sa2.appe
# ...

# %%
#divide the 
from pydub import AudioSegment
t1 = t1 * 1000 #Works in milliseconds,start time where i want to cut ,could be obtained from .wrd file .divide by 16000
t2 = t2 * 1000 #end time
newAudio = AudioSegment.from_wav("TRAIN\DR1\FCJF0\SA1.wav")
newAudio = newAudio[t1:t2]
newAudio.export('.wav', format="wav")

# %%
dr1='TRAIN/DR1'
# dr2='TRAIN\DR2'
# dr3='TRAIN\DR3'
# dr4='TRAIN\DR4'
# dr5='TRAIN\DR5'
# dr6='TRAIN\DR6'
# dr7='TRAIN\DR7'
# dr8='TRAIN\DR8'
# sa1='\SA1.WAV'
# sa2='\SA2.WAV'
# dr1=[os.path.join(dr1,p) for p in sorted(os.listdir(dr1))]
# dr2=[os.path.join(dr2,p) for p in sorted(os.listdir(dr2))]
# dr3=[os.path.join(dr3,p) for p in sorted(os.listdir(dr3))]
# dr4=[os.path.join(dr4,p) for p in sorted(os.listdir(dr4))]
# dr5=[os.path.join(dr5,p) for p in sorted(os.listdir(dr5))]
# dr6=[os.path.join(dr6,p) for p in sorted(os.listdir(dr6))]
# dr7=[os.path.join(dr7,p) for p in sorted(os.listdir(dr7))]
# dr8=[os.path.join(dr8,p) for p in sorted(os.listdir(dr8))]

for i in dr1:
    sa1_wav=os.path.join(i,'SA1.WAV')
    
    sa2_wav=os.path.join(i,'SA2.WAV')
    sa1_wrd=os.path.join(i,'SA1.WRD')
    sa2_wrd=os.path.join(i,'SA2.WRD')
    f = open(sa1_wrd, "r")
    wrd1=f.readline()
    str_wrd1=wrd1.split(" ")
    start_time=int(str_wrd1[0])/16000
    end_time=int(str_wrd1[1])/16000
    sa1_wav_to_cut= AudioSegment.from_wav(sa1_wav)
    wrd1_wav=sa1_wav_to_cut[start_time:end_time]
    wrd1_wav.export('words\\'+str_wrd1[2]+'\\')
for i in dr1_list_sa1:
    x=i.split('\\')
    x[2]#name
    sph=SPHFile(i)
    a=os.path.join(x[0],x[1])
    txt=os.path.join(a,x[2])
    txt1=os.path.join(txt,'SA1.Wa')
    wrd=os.path.join(txt,'SA1.wrd')
    f = open(txt, "r")
    for line in f:
        t=line.split(" ")
        start_time=(int(t[0])/16000)
        end_time=(int(t[1])/16000)
    sph.write_wav('sa1\\'+x[2]+'_sa1.WAV',start_time,end_time)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-37622fbeb0ac> in <module>
#      24     sa1_wrd=os.path.join(i,'SA1.WRD')
#      25     sa2_wrd=os.path.join(i,'SA2.WRD')
# ---> 26     f = open(sa1_wrd, "r")
#      27     wrd1=f.readline()
#      28     str_wrd1=wrd1.split(" ")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'T/SA1.WRD'

# %%
#f=open(dr1_list_sa1[0],"r")

# %%
x=f.readline()
print(x)
# Out:
# 3050 5723 she

# %%
y=x.split(" ")

# %%
y[0]
# Out:
# '3050'

# %%
x=dr1_list_sa1[0].split("\\")
x[2]
# Out:
# 'FCJF0'

# %%
f=open(dr1_list_sa1[0],"r")
wrd1=f.readline()#she
wrd2=f.readline()#had
wrd3=f.readline()#your
wrd4=f.readline()#dark
wrd5=f.readline()#suit
wrd6=f.readline()#in
wrd7=f.readline()#greasy
wrd8=f.readline()#wash
wrd9=f.readline()#water
wrd10=f.readline()#all
wrd11=f.readline()#year

# %%
str=f.readline()
path='TRAIN//DR2//FAEM0/SA1.wrd'
f = open(path, "r")
# Out:
# ''

# %%
# to derive mfcc features from word file
from python_speech_features import mfcc
import scipy.io.wavfile as wav
(rate,sig) = wav.read("sa1\\FAEM0_sa1.WAV")
mfcc_feat = mfcc(sig,rate)

# %%
mfcc_feat[0]
# Out:
# array([  8.06583174, -21.42017881, -23.97431235, -12.65305215,
#         -6.06251235, -22.10010506, -10.3301539 ,  -3.51757955,
#          6.57771073,  -2.51548658,  -7.09264729,  -4.50345301,
#          1.35157517])
