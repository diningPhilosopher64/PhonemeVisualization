# %%
from sphfile import SPHFile
import os
from pydub import AudioSegment
import glob
import subprocess
from python_speech_features import logfbank
import scipy.io.wavfile as wav
import scipy
import math

import numpy as np
import shutil
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler


import subprocess

import math


import warnings
warnings.filterwarnings(action='once')
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
# Out:
# /home/sourabh/anaconda2/envs/py3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /home/sourabh/anaconda2/envs/py3/lib/python3.6/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
bottleneck_9d  = np.load("bottleneck_layer_output.npy")
output_labels = np.load("output_labels.npy")
sklearn_lda = LDA(n_components=3)
bottleneck_3d = sklearn_lda.fit_transform(bottleneck_9d,output_labels)

# %%
bottleneck_3d.shape
# Out:
# (402531, 3)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D as ax

# %matplotlib notebook

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.gca(projection='3d')

x_cordinates = np.array(bottleneck_3d[:,0:1])
y_cordinates = np.array(bottleneck_3d[:,1:2])
z_cordinates = np.array(bottleneck_3d[:,2:3])

ax.scatter(x_cordinates,y_cordinates, z_cordinates)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
indices = np.argwhere(output_labels == 'th')
sh_3d = bottleneck_3d[indices]
sh_3d = sh_3d[:,0,:]

# %%
indices = np.argwhere(output_labels == 'r')
aa_3d = bottleneck_3d[indices]
aa_3d = aa_3d[:,0,:]

# %%
aa_3d = aa_3d[:1272]

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.gca(projection='3d')


x_cordinates_sh = np.array(sh_3d[:,0:1])
y_cordinates_sh = np.array(sh_3d[:,1:2])
z_cordinates_sh = np.array(sh_3d[:,2:3])

ax.scatter(x_cordinates_sh,y_cordinates_sh, z_cordinates_sh)


x_cordinates_aa = np.array(aa_3d[:,0:1])
y_cordinates_aa = np.array(aa_3d[:,1:2])
z_cordinates_aa = np.array(aa_3d[:,2:3])

ax.scatter(x_cordinates_aa,y_cordinates_aa, z_cordinates_aa)
# Out:
# <img src="data:image/png;base64,..." width="640">
